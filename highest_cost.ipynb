# %%
# imports
import pandas as pd
import numpy as np

# %%
# importing csv's
claims = pd.read_csv('claims.csv')
members = pd.read_csv('members.csv')

# %%
# Billed total calculation
total_billed = claims['billed_amount'].sum().round(2)

# Paid total calculation
total_paid = claims['paid_amount'].sum().round(2)

# Difference between billed and paid amounts
total_difference = total_billed - total_paid

# Total number of claims
num_claims = claims['claim_id'].count()

# Average Unpaid Claim Cost calculation
avg_unpaid = (total_difference / num_claims).round(2)

# %%
# Reporting
print(f'The total billed amount is ${total_billed}.')
print(f'The total paid amount is ${total_paid}.')
print(f'The total difference is ${total_difference.round(2)}.')
print(f'There are {num_claims} claims in total, with an Average Unpaid Claim Cost of ${avg_unpaid}.')
# Out:
# The total billed amount is $2062165.05.
# The total paid amount is $1550744.91.
# The total difference is $511420.14.
# There are 449 claims in total, with an Average Unpaid Claim Cost of $1139.02.
